# %% [markdown]
# ## Pré-processamento de Metabolômica Não Direcionada
# ========================================
#
# O fluxo de trabalho universal para metabolômica não direcionada consiste sempre na detecção de `features` nos arquivos de amostra individuais de MS e sua vinculação a `consensus features` com valores comuns de m/z e tempo de retenção. Além disso, existem etapas opcionais, como detecção de adutos e anotação de `features` com espectros `MS2` associados.

# %%
# !pip install pyopenms

# %%
from urllib.request import urlretrieve

gh = "https://raw.githubusercontent.com/OpenMS/pyopenms-docs/master"
urlretrieve(gh + "/src/data/Metabolomics_1.mzML", "Metabolomics_1.mzML")
urlretrieve(gh + "/src/data/Metabolomics_2.mzML", "Metabolomics_2.mzML")
# Out:
# ('Metabolomics_2.mzML', <http.client.HTTPMessage at 0x7f743410bd10>)

# %%
# !mkdir data

# %%
import os

os.chdir('data')
os.getcwd()
# Out:
# '/home/rsilva/Desktop/workshop/notebooks/data'

# %%
# !python ../download_massive.py ftp://massive-ftp.ucsd.edu/v03/MSV000085496/
# Out:
# /home/rsilva/Desktop/workshop/notebooks/data/../download_massive.py:10: SyntaxWarning: invalid escape sequence '\d'
#   dr = re.sub('.+edu/(v\d+/M.+)', '\\1', massive_url)
# Downloading 200525_Dog_4h_01.mzXML...
# --2025-09-30 07:37:40--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Dog_4h_01.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Dog_4h_01.mzML’
#
# 200525_Dog_4h_01.mz     [           <=>      ]  21,76M   879KB/s    in 45s
#
# 2025-09-30 07:38:26 (497 KB/s) - ‘200525_Dog_4h_01.mzML’ saved [22818869]
#
# Downloading 200525_Dog_4h_02.mzXML...
# --2025-09-30 07:38:26--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Dog_4h_02.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Dog_4h_02.mzML’
#
# 200525_Dog_4h_02.mz     [       <=>          ]  21,67M  1,68MB/s    in 30s
#
# 2025-09-30 07:38:57 (748 KB/s) - ‘200525_Dog_4h_02.mzML’ saved [22720571]
#
# Downloading 200525_Dog_4h_03.mzXML...
# --2025-09-30 07:38:57--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Dog_4h_03.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Dog_4h_03.mzML’
#
# 200525_Dog_4h_03.mz     [          <=>       ]  21,50M  1,58MB/s    in 28s
#
# 2025-09-30 07:39:26 (779 KB/s) - ‘200525_Dog_4h_03.mzML’ saved [22547181]
#
# Downloading 200525_Dog_Blank_01.mzXML...
# --2025-09-30 07:39:26--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Dog_Blank_01.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Dog_Blank_01.mzML’
#
# 200525_Dog_Blank_01     [             <=>    ]  21,24M  1,83MB/s    in 25s
#
# 2025-09-30 07:39:52 (859 KB/s) - ‘200525_Dog_Blank_01.mzML’ saved [22271287]
#
# Downloading 200525_Dog_Blank_02.mzXML...
# --2025-09-30 07:39:52--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Dog_Blank_02.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Dog_Blank_02.mzML’
#
# 200525_Dog_Blank_02     [                 <=>]  20,41M   691KB/s    in 34s
#
# 2025-09-30 07:40:27 (618 KB/s) - ‘200525_Dog_Blank_02.mzML’ saved [21405684]
#
# Downloading 200525_Dog_Blank_03.mzXML...
# --2025-09-30 07:40:27--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Dog_Blank_03.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Dog_Blank_03.mzML’
#
# 200525_Dog_Blank_03     [       <=>          ]  20,14M   260KB/s    in 62s
#
# 2025-09-30 07:41:30 (333 KB/s) - ‘200525_Dog_Blank_03.mzML’ saved [21123257]
#
# Downloading 200525_HUMAN_4h_01.mzXML...
# --2025-09-30 07:41:30--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_HUMAN_4h_01.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_HUMAN_4h_01.mzML’
#
# 200525_HUMAN_4h_01.     [         <=>        ]  23,45M  1,20MB/s    in 54s
#
# 2025-09-30 07:42:25 (441 KB/s) - ‘200525_HUMAN_4h_01.mzML’ saved [24588238]
#
# Downloading 200525_HUMAN_4h_02.mzXML...
# --2025-09-30 07:42:25--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_HUMAN_4h_02.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_HUMAN_4h_02.mzML’
#
# 200525_HUMAN_4h_02.     [           <=>      ]  23,83M  1004KB/s    in 44s
#
# 2025-09-30 07:43:10 (557 KB/s) - ‘200525_HUMAN_4h_02.mzML’ saved [24990089]
#
# Downloading 200525_HUMAN_4h_03.mzXML...
# --2025-09-30 07:43:10--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_HUMAN_4h_03.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_HUMAN_4h_03.mzML’
#
# 200525_HUMAN_4h_03.     [             <=>    ]  24,05M  1,20MB/s    in 26s
#
# 2025-09-30 07:43:37 (948 KB/s) - ‘200525_HUMAN_4h_03.mzML’ saved [25223102]
#
# Downloading 200525_HUMAN_Blank_01.mzXML...
# --2025-09-30 07:43:37--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_HUMAN_Blank_01.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_HUMAN_Blank_01.mzML’
#
# 200525_HUMAN_Blank_     [           <=>      ]  22,88M   825KB/s    in 36s
#
# 2025-09-30 07:44:13 (658 KB/s) - ‘200525_HUMAN_Blank_01.mzML’ saved [23993950]
#
# Downloading 200525_HUMAN_Blank_02.mzXML...
# --2025-09-30 07:44:13--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_HUMAN_Blank_02.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_HUMAN_Blank_02.mzML’
#
# 200525_HUMAN_Blank_     [ <=>                ]  22,57M   610KB/s    in 39s
#
# 2025-09-30 07:44:53 (596 KB/s) - ‘200525_HUMAN_Blank_02.mzML’ saved [23665049]
#
# Downloading 200525_HUMAN_Blank_03.mzXML...
# --2025-09-30 07:44:53--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_HUMAN_Blank_03.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_HUMAN_Blank_03.mzML’
#
# 200525_HUMAN_Blank_     [   <=>              ]  22,45M   951KB/s    in 28s
#
# 2025-09-30 07:45:22 (810 KB/s) - ‘200525_HUMAN_Blank_03.mzML’ saved [23538183]
#
# Downloading 200525_Mou_4h_01.mzXML...
# --2025-09-30 07:45:22--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Mou_4h_01.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Mou_4h_01.mzML’
#
# 200525_Mou_4h_01.mz     [            <=>     ]  21,22M   899KB/s    in 25s
#
# 2025-09-30 07:45:48 (868 KB/s) - ‘200525_Mou_4h_01.mzML’ saved [22247980]
#
# Downloading 200525_Mou_4h_02.mzXML...
# --2025-09-30 07:45:48--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Mou_4h_02.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Mou_4h_02.mzML’
#
# 200525_Mou_4h_02.mz     [            <=>     ]  21,55M   540KB/s    in 34s
#
# 2025-09-30 07:46:23 (658 KB/s) - ‘200525_Mou_4h_02.mzML’ saved [22596251]
#
# Downloading 200525_Mou_4h_03.mzXML...
# --2025-09-30 07:46:23--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Mou_4h_03.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Mou_4h_03.mzML’
#
# 200525_Mou_4h_03.mz     [   <=>              ]  21,42M   854KB/s    in 40s
#
# 2025-09-30 07:47:03 (553 KB/s) - ‘200525_Mou_4h_03.mzML’ saved [22456592]
#
# Downloading 200525_Mou_Blank_01.mzXML...
# --2025-09-30 07:47:03--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Mou_Blank_01.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Mou_Blank_01.mzML’
#
# 200525_Mou_Blank_01     [                <=> ]  21,18M   320KB/s    in 35s
#
# 2025-09-30 07:47:39 (617 KB/s) - ‘200525_Mou_Blank_01.mzML’ saved [22206861]
#
# Downloading 200525_Mou_Blank_02.mzXML...
# --2025-09-30 07:47:39--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Mou_Blank_02.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Mou_Blank_02.mzML’
#
# 200525_Mou_Blank_02     [ <=>                ]  21,11M  1,06MB/s    in 32s
#
# 2025-09-30 07:48:12 (684 KB/s) - ‘200525_Mou_Blank_02.mzML’ saved [22138301]
#
# Downloading 200525_Mou_Blank_03.mzXML...
# --2025-09-30 07:48:12--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Mou_Blank_03.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Mou_Blank_03.mzML’
#
# 200525_Mou_Blank_03     [          <=>       ]  21,60M   442KB/s    in 36s
#
# 2025-09-30 07:48:49 (606 KB/s) - ‘200525_Mou_Blank_03.mzML’ saved [22654665]
#
# Downloading 200525_Rat_4h_01.mzXML...
# --2025-09-30 07:48:49--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Rat_4h_01.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Rat_4h_01.mzML’
#
# 200525_Rat_4h_01.mz     [                <=> ]  22,20M   963KB/s    in 36s
#
# 2025-09-30 07:49:26 (636 KB/s) - ‘200525_Rat_4h_01.mzML’ saved [23283518]
#
# Downloading 200525_Rat_4h_02.mzXML...
# --2025-09-30 07:49:26--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Rat_4h_02.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Rat_4h_02.mzML’
#
# 200525_Rat_4h_02.mz     [    <=>             ]  21,99M  1,44MB/s    in 48s
#
# 2025-09-30 07:50:15 (465 KB/s) - ‘200525_Rat_4h_02.mzML’ saved [23062931]
#
# Downloading 200525_Rat_4h_03.mzXML...
# --2025-09-30 07:50:15--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Rat_4h_03.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Rat_4h_03.mzML’
#
# 200525_Rat_4h_03.mz     [           <=>      ]  21,72M   855KB/s    in 51s
#
# 2025-09-30 07:51:07 (437 KB/s) - ‘200525_Rat_4h_03.mzML’ saved [22774483]
#
# Downloading 200525_Rat_Blank_01.mzXML...
# --2025-09-30 07:51:07--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Rat_Blank_01.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Rat_Blank_01.mzML’
#
# 200525_Rat_Blank_01     [           <=>      ]  20,68M  1,30MB/s    in 25s
#
# 2025-09-30 07:51:33 (832 KB/s) - ‘200525_Rat_Blank_01.mzML’ saved [21687158]
#
# Downloading 200525_Rat_Blank_02.mzXML...
# --2025-09-30 07:51:33--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Rat_Blank_02.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Rat_Blank_02.mzML’
#
# 200525_Rat_Blank_02     [    <=>             ]  21,51M   701KB/s    in 32s
#
# 2025-09-30 07:52:06 (693 KB/s) - ‘200525_Rat_Blank_02.mzML’ saved [22555232]
#
# Downloading 200525_Rat_Blank_03.mzXML...
# --2025-09-30 07:52:06--  https://massive.ucsd.edu/ProteoSAFe/DownloadResultFile?file=f.MSV000085496%2Fccms_peak%2F200525_Rat_Blank_03.mzML
# Resolving massive.ucsd.edu (massive.ucsd.edu)... 132.249.211.33
# Connecting to massive.ucsd.edu (massive.ucsd.edu)|132.249.211.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘200525_Rat_Blank_03.mzML’
#
# 200525_Rat_Blank_03     [            <=>     ]  21,38M   809KB/s    in 37s
#
# 2025-09-30 07:52:44 (592 KB/s) - ‘200525_Rat_Blank_03.mzML’ saved [22414527]
#
# Traceback (most recent call last):
#   File "/home/rsilva/Desktop/workshop/notebooks/data/../download_massive.py", line 28, in <module>
#   File "/home/rsilva/Desktop/workshop/notebooks/data/../download_massive.py", line 24, in downloadMassIVE
#   File "/home/rsilva/miniconda3/envs/pyopenms/lib/python3.12/ftplib.py", line 653, in quit
#     resp = self.voidcmd('QUIT')
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rsilva/miniconda3/envs/pyopenms/lib/python3.12/ftplib.py", line 286, in voidcmd
#     return self.voidresp()
#            ^^^^^^^^^^^^^^^
#   File "/home/rsilva/miniconda3/envs/pyopenms/lib/python3.12/ftplib.py", line 259, in voidresp
#     resp = self.getresp()
#            ^^^^^^^^^^^^^^
#   File "/home/rsilva/miniconda3/envs/pyopenms/lib/python3.12/ftplib.py", line 252, in getresp
#     raise error_temp(resp)
# ftplib.error_temp: 421 Timeout.

# %% [markdown]
# Para cada arquivo `mzML`, faça rastreamento de massa, pico de eluição e detecção de _features_.

# %%
import os

mzML_files = [f'data/{x}' for x in os.listdir('data') if 'aligned' not in x and 'feature' not in x]
mzML_files
# Out:
# ['data/200525_Mou_4h_02.mzML',
#  'data/200525_HUMAN_Blank_03.mzML',
#  'data/200525_Rat_Blank_03.mzML',
#  'data/200525_Dog_Blank_01.mzML',
#  'data/200525_HUMAN_4h_02.mzML',
#  'data/200525_Dog_Blank_03.mzML',
#  'data/200525_Rat_4h_01.mzML',
#  'data/200525_Dog_4h_03.mzML',
#  'data/200525_Mou_4h_03.mzML',
#  'data/200525_Mou_4h_01.mzML',
#  'data/200525_Rat_4h_03.mzML',
#  'data/200525_Dog_4h_01.mzML',
#  'data/200525_Rat_Blank_01.mzML',
#  'data/200525_Dog_4h_02.mzML',
#  'data/200525_Rat_4h_02.mzML',
#  'data/200525_Dog_Blank_02.mzML',
#  'data/200525_Mou_Blank_02.mzML',
#  'data/200525_Mou_Blank_03.mzML',
#  'data/200525_HUMAN_Blank_01.mzML',
#  'data/200525_Rat_Blank_02.mzML',
#  'data/200525_Mou_Blank_01.mzML',
#  'data/200525_HUMAN_Blank_02.mzML',
#  'data/200525_HUMAN_4h_01.mzML',
#  'data/200525_HUMAN_4h_03.mzML']

# %%
import pyopenms as oms
import os

#mzML_files = ["Metabolomics_1.mzML", "Metabolomics_2.mzML"]

def getFeatureMaps(mzML_list):
    feature_maps = []
    for file in mzML_list:
        # carregar os arquivos mzML file no objeto MSExperiment
        print('Processing file:', file) 
        exp = oms.MSExperiment()
        oms.MzMLFile().load(
            file, exp
        )  
    
        # detecção de 'traços'  de massa
        mass_traces = (
            []
        )  # criar lista vazia onde as massas serão armazenadas
        mtd = oms.MassTraceDetection()
        mtd_par = (
            mtd.getDefaults()
        )  # obter parâmetros padrão para edição
        mtd_par.setValue("mass_error_ppm", 15.0)  # instrumentos de alta resolução, exemplo: orbitraps
        mtd_par.setValue(
            "noise_threshold_int", 1.0e03
        )  # dependente dos dados (usualmente funciona para orbitraps)
        mtd.setParameters(mtd_par)  # definir os novos parâmetros
        mtd.run(exp, mass_traces, 0)  # executar detecção de massas
    
        # detecção de picos de eluição
        mass_traces_deconvol = []
        epd = oms.ElutionPeakDetection()
        epd_par = epd.getDefaults()
        epd_par.setValue(
            "width_filtering", "fixed"
        )  # Os filtros de parâmetros fixos removem traços fora do intervalo [min_fwhm: 1.0, max_fwhm: 60.0]
        epd.setParameters(epd_par)
        epd.detectPeaks(mass_traces, mass_traces_deconvol)
    
        # Detecção de features
        feature_map = oms.FeatureMap()  # features encontradas
        chrom_out = []  # lista de cromatogramas
        ffm = oms.FeatureFindingMetabo()
        ffm_par = ffm.getDefaults()
        ffm_par.setValue(
            "remove_single_traces", "true"
        )  # remove traços sem traços isotópicos satélite
        ffm.setParameters(ffm_par)
        ffm.run(mass_traces_deconvol, feature_map, chrom_out)
        feature_map.setUniqueIds()  # Atribui uma nova, id única válida por feature
        feature_map.setPrimaryMSRunPath(
            [file.encode()]
        )  # Ajusta o caminho do arquivo para o local dos aquivos mzML
        feature_maps.append(feature_map)
    
    return feature_maps

feature_maps = getFeatureMaps(mzML_files)
# Out:
# Processing file: data/200525_Mou_4h_02.mzML
#     Progress of 'mass trace detection':
#     -- done [took 0.07 s (CPU), 0.03 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.25 s (CPU), 0.02 s (Wall)] --
# Processing file: data/200525_HUMAN_Blank_03.mzML
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Mou_4h_02.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_HUMAN_Blank_03.mzML': Required attribute 'softwareRef' not present!
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.10 s (CPU), 0.01 s (Wall)] --
#     Progress of 'mass trace detection':
#     -- done [took 0.05 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.22 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.14 s (CPU), 0.01 s (Wall)] --
# Processing file: data/200525_Rat_Blank_03.mzML
#     Progress of 'mass trace detection':
# Processing file: data/200525_Dog_Blank_01.mzML
#     -- done [took 0.07 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.23 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.14 s (CPU), 0.01 s (Wall)] --
#     Progress of 'mass trace detection':
#     -- done [took 0.07 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Rat_Blank_03.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Dog_Blank_01.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_HUMAN_4h_02.mzML': Required attribute 'softwareRef' not present!
#     -- done [took 0.21 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.10 s (CPU), 0.01 s (Wall)] --
# Processing file: data/200525_HUMAN_4h_02.mzML
#     Progress of 'mass trace detection':
#     -- done [took 0.05 s (CPU), 0.03 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.25 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.14 s (CPU), 0.01 s (Wall)] --
# Processing file: data/200525_Dog_Blank_03.mzML
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Dog_Blank_03.mzML': Required attribute 'softwareRef' not present!
#     Progress of 'mass trace detection':
#     -- done [took 0.03 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.22 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.10 s (CPU), 0.01 s (Wall)] --
# Processing file: data/200525_Rat_4h_01.mzML
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Rat_4h_01.mzML': Required attribute 'softwareRef' not present!
#     Progress of 'mass trace detection':
#     -- done [took 0.03 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.24 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
# Processing file: data/200525_Dog_4h_03.mzML
#     -- done [took 0.15 s (CPU), 0.01 s (Wall)] --
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Dog_4h_03.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Mou_4h_03.mzML': Required attribute 'softwareRef' not present!
#     Progress of 'mass trace detection':
# Processing file: data/200525_Mou_4h_03.mzML
#     -- done [took 0.03 s (CPU), 0.03 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.21 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.11 s (CPU), 0.01 s (Wall)] --
# Processing file: data/200525_Mou_4h_01.mzML
#     Progress of 'mass trace detection':
#     -- done [took 0.03 s (CPU), 0.03 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.21 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.09 s (CPU), 0.01 s (Wall)] --
#     Progress of 'mass trace detection':
#     -- done [took 0.04 s (CPU), 0.03 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.30 s (CPU), 0.03 s (Wall)] --
#     Progress of 'assembling mass traces to features':
# Processing file: data/200525_Rat_4h_03.mzML
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Mou_4h_01.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Rat_4h_03.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Dog_4h_01.mzML': Required attribute 'softwareRef' not present!
#     -- done [took 0.11 s (CPU), 0.01 s (Wall)] --
#     Progress of 'mass trace detection':
#     -- done [took 0.04 s (CPU), 0.02 s (Wall)] --
# Processing file: data/200525_Dog_4h_01.mzML
#     Progress of 'elution peak detection':
#     -- done [took 0.23 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.14 s (CPU), 0.01 s (Wall)] --
#     Progress of 'mass trace detection':
#     -- done [took 0.07 s (CPU), 0.03 s (Wall)] --
# Processing file: data/200525_Rat_Blank_01.mzML
#     Progress of 'elution peak detection':
#     -- done [took 0.23 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.15 s (CPU), 0.01 s (Wall)] --
#     Progress of 'mass trace detection':
#     -- done [took 0.03 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.21 s (CPU), 0.02 s (Wall)] --
# Processing file: data/200525_Dog_4h_02.mzML
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.09 s (CPU), 0.01 s (Wall)] --
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Rat_Blank_01.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Dog_4h_02.mzML': Required attribute 'softwareRef' not present!
#     Progress of 'mass trace detection':
#     -- done [took 0.04 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
# Processing file: data/200525_Rat_4h_02.mzML
#     -- done [took 0.26 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.15 s (CPU), 0.01 s (Wall)] --
#     Progress of 'mass trace detection':
#     -- done [took 0.03 s (CPU), 0.03 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.25 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
# Processing file: data/200525_Dog_Blank_02.mzML
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Rat_4h_02.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Dog_Blank_02.mzML': Required attribute 'softwareRef' not present!
#     -- done [took 0.10 s (CPU), 0.01 s (Wall)] --
# Processing file: data/200525_Mou_Blank_02.mzML
#     Progress of 'mass trace detection':
#     -- done [took 0.06 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.25 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.10 s (CPU), 0.01 s (Wall)] --
#     Progress of 'mass trace detection':
#     -- done [took 0.05 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.22 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.14 s (CPU), 0.01 s (Wall)] --
# Processing file: data/200525_Mou_Blank_03.mzML
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Mou_Blank_02.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Mou_Blank_03.mzML': Required attribute 'softwareRef' not present!
#     Progress of 'mass trace detection':
# Processing file: data/200525_HUMAN_Blank_01.mzML
#     -- done [took 0.07 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.24 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.15 s (CPU), 0.01 s (Wall)] --
#     Progress of 'mass trace detection':
#     -- done [took 0.06 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
# Processing file: data/200525_Rat_Blank_02.mzML
#     -- done [took 0.21 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.10 s (CPU), 0.01 s (Wall)] --
# Processing file: data/200525_Mou_Blank_01.mzML
#     Progress of 'mass trace detection':
#     -- done [took 0.06 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.24 s (CPU), 0.02 s (Wall)] --
# Processing file: data/200525_HUMAN_Blank_02.mzML
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.15 s (CPU), 0.01 s (Wall)] --
#     Progress of 'mass trace detection':
#     -- done [took 0.04 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.23 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.14 s (CPU), 0.01 s (Wall)] --
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_HUMAN_Blank_01.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Rat_Blank_02.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Mou_Blank_01.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_HUMAN_Blank_02.mzML': Required attribute 'softwareRef' not present!
#     Progress of 'mass trace detection':
#     -- done [took 0.03 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.22 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.14 s (CPU), 0.01 s (Wall)] --
# Processing file: data/200525_HUMAN_4h_01.mzML
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_HUMAN_4h_01.mzML': Required attribute 'softwareRef' not present!
#     Progress of 'mass trace detection':
#     -- done [took 0.04 s (CPU), 0.02 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.24 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.10 s (CPU), 0.01 s (Wall)] --
# Processing file: data/200525_HUMAN_4h_03.mzML
#     Progress of 'mass trace detection':
#     -- done [took 0.03 s (CPU), 0.03 s (Wall)] --
#     Progress of 'elution peak detection':
#     -- done [took 0.24 s (CPU), 0.02 s (Wall)] --
#     Progress of 'assembling mass traces to features':
#     -- done [took 0.10 s (CPU), 0.01 s (Wall)] --
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_HUMAN_4h_03.mzML': Required attribute 'softwareRef' not present!

# %%
len(feature_maps)
# Out:
# 24

# %%
len(mzML_files)
# Out:
# 24

# %% [markdown]
# Alinhe os tempos de retenção das _features_ com base no `mapa de features` com o maior número de _features_ (mapa de referência).

# %%
def alignFeatureRT(feature_maps):
    # use as reference for alignment, the file with the largest number of features
    # (works well if you have a pooled QC for example)
    ref_index = feature_maps.index(sorted(feature_maps, key=lambda x: x.size())[-1])
    
    aligner = oms.MapAlignmentAlgorithmPoseClustering()
    
    trafos = {}
    
    # parameter optimization
    aligner_par = aligner.getDefaults()
    aligner_par.setValue("max_num_peaks_considered", -1)  # infinite
    aligner_par.setValue(
        "pairfinder:distance_MZ:max_difference", 10.0
    )  # Never pair features with larger m/z distance
    aligner_par.setValue("pairfinder:distance_MZ:unit", "ppm")
    aligner.setParameters(aligner_par)
    aligner.setReference(feature_maps[ref_index])
    
    for feature_map in feature_maps[:ref_index] + feature_maps[ref_index + 1 :]:
        trafo = oms.TransformationDescription()  # save the transformed data points
        aligner.align(feature_map, trafo)
        trafos[feature_map.getMetaValue("spectra_data")[0].decode()] = trafo
        transformer = oms.MapAlignmentTransformer()
        transformer.transformRetentionTimes(feature_map, trafo, True)

    return trafos

trafos = alignFeatureRT(feature_maps)

# %% [markdown]
# Alinhar os arquivos `mzML` com base no alinhamento `FeatureMap` (opcional, somente para GNPS).

# %%
# align mzML files based on FeatureMap alignment and store as mzML files (for GNPS!)
def generateAlignedMzML(trafos, mzML_files):
    for file in mzML_files:
        exp = oms.MSExperiment()
        oms.MzMLFile().load(file, exp)
        exp.sortSpectra(True)
        exp.setMetaValue("mzML_path", file)
        if file not in trafos.keys():
            oms.MzMLFile().store(file[:-5] + "_aligned.mzML", exp)
            continue
        transformer = oms.MapAlignmentTransformer()
        trafo_description = trafos[file]
        transformer.transformRetentionTimes(exp, trafo_description, True)
        oms.MzMLFile().store(file[:-5] + "_aligned.mzML", exp)
    mzML_files = [file[:-5] + "_aligned.mzML" for file in mzML_files]
    return mzML_files

mzML_files = generateAlignedMzML(trafos, mzML_files)
# Out:
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Mou_4h_02.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_HUMAN_Blank_03.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Rat_Blank_03.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Dog_Blank_01.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_HUMAN_4h_02.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Dog_Blank_03.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Rat_4h_01.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Dog_4h_03.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Mou_4h_03.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Mou_4h_01.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Rat_4h_03.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Dog_4h_01.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Rat_Blank_01.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Dog_4h_02.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Rat_4h_02.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Dog_Blank_02.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Mou_Blank_02.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Mou_Blank_03.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_HUMAN_Blank_01.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Rat_Blank_02.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_Mou_Blank_01.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_HUMAN_Blank_02.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_HUMAN_4h_01.mzML': Required attribute 'softwareRef' not present!
# /__w/OpenMS/OpenMS/OpenMS/src/openms/source/FORMAT/HANDLERS/XMLHandler.cpp(105): While loading 'data/200525_HUMAN_4h_03.mzML': Required attribute 'softwareRef' not present!

# %%
mzML_files
# Out:
# ['data/200525_Mou_4h_02_aligned.mzML',
#  'data/200525_HUMAN_Blank_03_aligned.mzML',
#  'data/200525_Rat_Blank_03_aligned.mzML',
#  'data/200525_Dog_Blank_01_aligned.mzML',
#  'data/200525_HUMAN_4h_02_aligned.mzML',
#  'data/200525_Dog_Blank_03_aligned.mzML',
#  'data/200525_Rat_4h_01_aligned.mzML',
#  'data/200525_Dog_4h_03_aligned.mzML',
#  'data/200525_Mou_4h_03_aligned.mzML',
#  'data/200525_Mou_4h_01_aligned.mzML',
#  'data/200525_Rat_4h_03_aligned.mzML',
#  'data/200525_Dog_4h_01_aligned.mzML',
#  'data/200525_Rat_Blank_01_aligned.mzML',
#  'data/200525_Dog_4h_02_aligned.mzML',
#  'data/200525_Rat_4h_02_aligned.mzML',
#  'data/200525_Dog_Blank_02_aligned.mzML',
#  'data/200525_Mou_Blank_02_aligned.mzML',
#  'data/200525_Mou_Blank_03_aligned.mzML',
#  'data/200525_HUMAN_Blank_01_aligned.mzML',
#  'data/200525_Rat_Blank_02_aligned.mzML',
#  'data/200525_Mou_Blank_01_aligned.mzML',
#  'data/200525_HUMAN_Blank_02_aligned.mzML',
#  'data/200525_HUMAN_4h_01_aligned.mzML',
#  'data/200525_HUMAN_4h_03_aligned.mzML']

# %% [markdown]
# Mapear espectros MS2 para recursos como objetos `PeptideIdentification` (opcional, somente para GNPS).

# %%
def mapMS2(mzML_files, feature_maps):
    feature_maps_mapped = []
    use_centroid_rt = False
    use_centroid_mz = True
    mapper = oms.IDMapper()
    for file in mzML_files:
        exp = oms.MSExperiment()
        oms.MzMLFile().load(file, exp)
        for i, feature_map in enumerate(feature_maps):
            if feature_map.getMetaValue("spectra_data")[
                0
            ].decode() == exp.getMetaValue("mzML_path"):
                peptide_ids = []
                protein_ids = []
                mapper.annotate(
                    feature_map,
                    peptide_ids,
                    protein_ids,
                    use_centroid_rt,
                    use_centroid_mz,
                    exp,
                )
                fm_new = oms.FeatureMap(feature_map)
                fm_new.clear(False)
                # set unique identifiers to protein and peptide identifications
                prot_ids = []
                if len(feature_map.getProteinIdentifications()) > 0:
                    prot_id = feature_map.getProteinIdentifications()[0]
                    prot_id.setIdentifier(f"Identifier_{i}")
                    prot_ids.append(prot_id)
                fm_new.setProteinIdentifications(prot_ids)
                for feature in feature_map:
                    pep_ids = []
                    for pep_id in feature.getPeptideIdentifications():
                        pep_id.setIdentifier(f"Identifier_{i}")
                        pep_ids.append(pep_id)
                    feature.setPeptideIdentifications(pep_ids)
                    fm_new.push_back(feature)
                feature_maps_mapped.append(fm_new)
    feature_maps = feature_maps_mapped
    return feature_maps

feature_maps = mapMS2(mzML_files, feature_maps)
# Out:
# .
# <IDMapper warning: at least one feature has no convex hull - using centroid coordinates for matching> occurred 24 times
# ..
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (9 of 87)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (7 of 60)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (14 of 79)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (14 of 70)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (6 of 92)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (10 of 62)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (8 of 72)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (14 of 86)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (11 of 67)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (11 of 76)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (9 of 92)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (11 of 75)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (6 of 74)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (12 of 90)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (5 of 83)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (12 of 71)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (12 of 56)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (9 of 56)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (6 of 63)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (10 of 73)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (7 of 54)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (15 of 80)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (9 of 78)This might indicate a too low charge interval being tested.
# .
# <.> occurred 2 times
# Warning: a significant portion of your decharged molecules have gapped, even-numbered charge ladders (6 of 76)This might indicate a too low charge interval being tested.
# .
# <..> occurred 48 times
# IDMapper warning: at least one feature has no convex hull - using centroid coordinates for matching
# 3274 spectra and 0 chromatograms stored.
# <Loading metabolite isotope model with 5% RMS error> occurred 48 times
# 3277 spectra and 0 chromatograms stored.
# 3266 spectra and 0 chromatograms stored.
# <3274 spectra and 0 chromatograms stored.> occurred 2 times
# 3281 spectra and 0 chromatograms stored.
# 3271 spectra and 0 chromatograms stored.
# 3269 spectra and 0 chromatograms stored.
# 3277 spectra and 0 chromatograms stored.
# 3267 spectra and 0 chromatograms stored.
# 3274 spectra and 0 chromatograms stored.
# 3275 spectra and 0 chromatograms stored.
# 3273 spectra and 0 chromatograms stored.
# 3278 spectra and 0 chromatograms stored.
# 3275 spectra and 0 chromatograms stored.
# 3281 spectra and 0 chromatograms stored.
# 3274 spectra and 0 chromatograms stored.
# 3265 spectra and 0 chromatograms stored.
# 3283 spectra and 0 chromatograms stored.
# <3265 spectra and 0 chromatograms stored.> occurred 2 times
# 3272 spectra and 0 chromatograms stored.
# 3274 spectra and 0 chromatograms stored.
# 3275 spectra and 0 chromatograms stored.
# <3274 spectra and 0 chromatograms stored.> occurred 2 times
# 3272 spectra and 0 chromatograms stored.
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2326
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 348
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2335
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 324
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2322
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 335
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2319
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 329
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2341
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 373
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2328
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 320
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2319
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 387
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2326
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 363
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2317
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 334
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2326
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 348
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2328
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 387
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2326
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 350
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2316
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 340
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2331
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 368
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2331
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 375
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2325
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 361
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2321
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 303
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2327
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 308
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2360
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 360
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2316
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 366
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2327
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 295
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2351
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 343
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2339
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 387
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0
#
#
# Unassigned peptides: 0
# Peptides assigned to exactly one feature: 0
# Peptides assigned to multiple features: 0
# Unassigned and unidentified precursors: 2335
# Unidentified precursor assigned to exactly one feature: 0
# Unidentified precursor assigned to multiple features: 0
# Feature annotation with identifications:
#     no ID: 393
#     single ID: 0
#     multiple IDs (identical): 0
#     multiple IDs (divergent): 0

# %%
len(feature_maps)
# Out:
# 24

# %% [markdown]
# Detectar adutos (opcional, somente para SIRIUS e GNPS Ion Identity Molecular Networking).

# %%
def getAdducts(feature_maps):
    feature_maps_adducts = []
    for feature_map in feature_maps:
        mfd = oms.MetaboliteFeatureDeconvolution()
        mdf_par = mfd.getDefaults()
        mdf_par.setValue(
            "potential_adducts",
            [
                b"H:+:0.4",
                b"Na:+:0.2",
                b"NH4:+:0.2",
                b"H-1O-1:+:0.1",
                b"H-3O-2:+:0.1",
            ],
        )
        mfd.setParameters(mdf_par)
        feature_map_adduct = oms.FeatureMap()
        mfd.compute(feature_map, feature_map_adduct, oms.ConsensusMap(), oms.ConsensusMap())
        feature_maps_adducts.append(feature_map_adduct)
    feature_maps = feature_maps_adducts
    
    # for SIRIUS store the feature maps as featureXML files!
    for feature_map in feature_maps:
        oms.FeatureXMLFile().store(
            feature_map.getMetaValue("spectra_data")[0].decode()[:-4]
            + "featureXML",
            feature_map,
        )
    return feature_maps

feature_maps = getAdducts(feature_maps)
# Out:
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 19 of 143 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 132 to 159
# Found 159 putative edges (of 599) and avg hit-size of 0.955975
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.006277 seconds,  with objective value: 8.5608.
# ILP score is: 8.5608
# Agreeing charges: 234/234
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 28 of 134 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 112 to 130
# Found 130 putative edges (of 554) and avg hit-size of 1.07692
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.0039 seconds,  with objective value: 7.0724.
# ILP score is: 7.0724
# Agreeing charges: 196/196
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 44 of 173 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 144 to 169
# Found 169 putative edges (of 599) and avg hit-size of 1.12426
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.006231 seconds,  with objective value: 7.9164.
# ILP score is: 7.9164
# Agreeing charges: 232/232
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 30 of 141 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 118 to 140
# Found 140 putative edges (of 609) and avg hit-size of 1.07857
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.005571 seconds,  with objective value: 7.1196.
# ILP score is: 7.1196
# Agreeing charges: 200/200
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 38 of 167 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 137 to 164
# Found 164 putative edges (of 638) and avg hit-size of 1.07317
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.004138 seconds,  with objective value: 8.7672.
# ILP score is: 8.7672
# Agreeing charges: 238/238
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 38 of 129 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 94 to 108
# Found 108 putative edges (of 569) and avg hit-size of 1.23148
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.004168 seconds,  with objective value: 5.26.
# ILP score is: 5.26
# Agreeing charges: 152/152
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 39 of 180 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 150 to 178
# Found 178 putative edges (of 778) and avg hit-size of 1.07303
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.005322 seconds,  with objective value: 8.608.
# ILP score is: 8.608
# Agreeing charges: 266/266
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 30 of 150 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 126 to 150
# Found 150 putative edges (of 627) and avg hit-size of 1.05333
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.004786 seconds,  with objective value: 8.41.
# ILP score is: 8.41
# Agreeing charges: 224/224
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 35 of 136 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 105 to 128
# Found 128 putative edges (of 514) and avg hit-size of 1.10156
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.004008 seconds,  with objective value: 7.0476.
# ILP score is: 7.0476
# Agreeing charges: 188/188
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 23 of 145 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 128 to 155
# Found 155 putative edges (of 555) and avg hit-size of 0.993548
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.005254 seconds,  with objective value: 8.6204.
# ILP score is: 8.6204
# Agreeing charges: 230/230
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 45 of 166 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 136 to 156
# Found 156 putative edges (of 700) and avg hit-size of 1.17949
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.005044 seconds,  with objective value: 7.424.
# ILP score is: 7.424
# Agreeing charges: 216/216
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 31 of 140 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 113 to 136
# Found 136 putative edges (of 545) and avg hit-size of 1.06618
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.004619 seconds,  with objective value: 8.0232.
# ILP score is: 8.0232
# Agreeing charges: 200/200
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 45 of 158 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 121 to 145
# Found 145 putative edges (of 647) and avg hit-size of 1.14483
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.004814 seconds,  with objective value: 7.6744.
# ILP score is: 7.6744
# Agreeing charges: 206/206
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 38 of 153 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 122 to 147
# Found 147 putative edges (of 646) and avg hit-size of 1.09524
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.004839 seconds,  with objective value: 7.6664.
# ILP score is: 7.6664
# Agreeing charges: 214/214
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 43 of 164 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 134 to 150
# Found 150 putative edges (of 678) and avg hit-size of 1.2
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.004951 seconds,  with objective value: 6.6532.
# ILP score is: 6.6532
# Agreeing charges: 222/222
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 36 of 143 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 114 to 131
# Found 131 putative edges (of 729) and avg hit-size of 1.16031
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.004188 seconds,  with objective value: 6.654.
# ILP score is: 6.654
# Agreeing charges: 188/188
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 25 of 134 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 115 to 139
# Found 139 putative edges (of 541) and avg hit-size of 1.01439
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.004575 seconds,  with objective value: 6.7272.
# ILP score is: 6.7272
# Agreeing charges: 194/194
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 36 of 145 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 115 to 141
# Found 141 putative edges (of 574) and avg hit-size of 1.07801
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.005378 seconds,  with objective value: 7.6524.
# ILP score is: 7.6524
# Agreeing charges: 196/196
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 41 of 151 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 119 to 141
# Found 141 putative edges (of 709) and avg hit-size of 1.13475
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.004527 seconds,  with objective value: 7.5748.
# ILP score is: 7.5748
# Agreeing charges: 198/198
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 47 of 171 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 139 to 161
# Found 161 putative edges (of 677) and avg hit-size of 1.15528
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.005326 seconds,  with objective value: 7.4556.
# ILP score is: 7.4556
# Agreeing charges: 224/224
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 32 of 122 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 97 to 112
# Found 112 putative edges (of 498) and avg hit-size of 1.16071
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.002956 seconds,  with objective value: 5.7732.
# ILP score is: 5.7732
# Agreeing charges: 156/156
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 33 of 144 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 115 to 137
# Found 137 putative edges (of 677) and avg hit-size of 1.08029
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.004112 seconds,  with objective value: 6.874.
# ILP score is: 6.874
# Agreeing charges: 204/204
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 39 of 160 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 129 to 161
# Found 161 putative edges (of 688) and avg hit-size of 1.04969
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.006706 seconds,  with objective value: 8.782.
# ILP score is: 8.782
# Agreeing charges: 218/218
# MassExplainer table size: 312
# Generating Masses with threshold: -6.90776 ...
# done
# 36 of 141 valid net charge compomer results did not pass the feature charge constraints
# Inferring edges raised edge count from 111 to 131
# Found 131 putative edges (of 721) and avg hit-size of 1.1374
# Using solver 'coinor' ...
# Optimal solution found!
#  Branch and cut took 0.003266 seconds,  with objective value: 7.5652.
# ILP score is: 7.5652
# Agreeing charges: 192/192

# %%
len(feature_maps)
# Out:
# 24

# %% [markdown]
# Vincular _features_ em um `ConsensusMap`.

# %%
def generateConsensusMap(feature_maps, consensus_filename="FeatureMatrix.consensusXML"):
    feature_grouper = oms.FeatureGroupingAlgorithmKD()
    
    consensus_map = oms.ConsensusMap()
    file_descriptions = consensus_map.getColumnHeaders()
    
    for i, feature_map in enumerate(feature_maps):
        file_description = file_descriptions.get(i, oms.ColumnHeader())
        file_description.filename = os.path.basename(
            feature_map.getMetaValue("spectra_data")[0].decode()
        )
        file_description.size = feature_map.size()
        file_descriptions[i] = file_description
    
    feature_grouper.group(feature_maps, consensus_map)
    consensus_map.setColumnHeaders(file_descriptions)
    consensus_map.setUniqueIds()
    oms.ConsensusXMLFile().store("FeatureMatrix.consensusXML", consensus_map)
    return consensus_map

consensus_map = generateConsensusMap(feature_maps)
# Out:
#     Progress of 'computing RT transformations':
#     -- done [took 0.03 s (CPU), 0.03 s (Wall)] --
#     Progress of 'linking features':
#     -- done [took 0.06 s (CPU), 0.06 s (Wall)] --

# %% [markdown]
# Obter uma matriz de _features_ final em um formato de tabela, exportando as _features_ `consensus` em um `DataFrame do pandas`.

# %%
df = consensus_map.get_df()
df
# Out:
#                      sequence  charge           RT          mz   quality  \
# id
# 14739944058528654579     None       1  2246.113352  438.380326  0.001906
# 4157342119469212697      None       1  2238.935716  526.432956  0.003521
# 12302576997318969048     None       1  2099.446080  790.587144  0.003364
# 16994532679487893418     None       1  2137.086734  383.207725  0.001177
# 16111634120984322021     None       1  2148.418678  619.909116  0.000275
# ...                       ...     ...          ...         ...       ...
# 6203773306922151309      None       2  2160.010000  530.335074  0.000505
# 17957731810262048765     None       1  2232.490000  578.936439  0.000507
# 2341387033982192385      None       2  2012.010000  982.553693  0.000084
# 6669415735134456905      None       1  2123.760000  343.221418  0.000582
# 10606136495986113371     None       1  2012.010000  997.528633  0.000307
#
#                       200525_HUMAN_Blank_01.mzML  200525_HUMAN_Blank_02.mzML  \
# id
# 14739944058528654579                1.265751e+06                1.097600e+06
# 4157342119469212697                 1.977040e+06                1.890943e+06
# 12302576997318969048                1.792398e+06                1.531315e+06
# 16994532679487893418                8.185056e+05                8.419818e+05
# 16111634120984322021                1.639494e+05                1.622231e+05
# ...                                          ...                         ...
# 6203773306922151309                 0.000000e+00                0.000000e+00
# 17957731810262048765                0.000000e+00                0.000000e+00
# 2341387033982192385                 0.000000e+00                0.000000e+00
# 6669415735134456905                 0.000000e+00                0.000000e+00
# 10606136495986113371                0.000000e+00                0.000000e+00
#
#                       200525_Mou_4h_02.mzML  200525_Mou_4h_01.mzML  \
# id
# 14739944058528654579           1.146201e+06            1075307.125
# 4157342119469212697            1.976774e+06            1976585.125
# 12302576997318969048           1.608213e+06            1558720.625
# 16994532679487893418           7.111176e+05             806296.500
# 16111634120984322021           1.492542e+05             152787.750
# ...                                     ...                    ...
# 6203773306922151309            0.000000e+00                  0.000
# 17957731810262048765           0.000000e+00                  0.000
# 2341387033982192385            0.000000e+00                  0.000
# 6669415735134456905            0.000000e+00                  0.000
# 10606136495986113371           0.000000e+00                  0.000
#
#                       200525_Mou_Blank_03.mzML  ...  200525_HUMAN_4h_03.mzML  \
# id                                              ...
# 14739944058528654579              1.170430e+06  ...             1.111038e+06
# 4157342119469212697               1.975116e+06  ...             2.032305e+06
# 12302576997318969048              1.591925e+06  ...             1.532721e+06
# 16994532679487893418              7.066050e+05  ...             7.648841e+05
# 16111634120984322021              1.774465e+05  ...             1.555899e+05
# ...                                        ...  ...                      ...
# 6203773306922151309               0.000000e+00  ...             3.933802e+05
# 17957731810262048765              0.000000e+00  ...             4.031701e+05
# 2341387033982192385               0.000000e+00  ...             6.481848e+04
# 6669415735134456905               0.000000e+00  ...             4.083494e+05
# 10606136495986113371              0.000000e+00  ...             1.731798e+05
#
#                       200525_Dog_4h_01.mzML  200525_Dog_Blank_02.mzML  \
# id
# 14739944058528654579           1.176974e+06              1.103988e+06
# 4157342119469212697            1.950890e+06              1.842646e+06
# 12302576997318969048           1.542612e+06              1.756035e+06
# 16994532679487893418           6.876800e+05              6.781026e+05
# 16111634120984322021           1.567735e+05              1.579209e+05
# ...                                     ...                       ...
# 6203773306922151309            0.000000e+00              0.000000e+00
# 17957731810262048765           0.000000e+00              0.000000e+00
# 2341387033982192385            0.000000e+00              0.000000e+00
# 6669415735134456905            0.000000e+00              0.000000e+00
# 10606136495986113371           0.000000e+00              0.000000e+00
#
#                       200525_HUMAN_4h_02.mzML  200525_Rat_Blank_02.mzML  \
# id
# 14739944058528654579             1.128128e+06              1.174037e+06
# 4157342119469212697              2.011819e+06              1.840831e+06
# 12302576997318969048             1.525446e+06              1.712583e+06
# 16994532679487893418             8.629775e+05              7.347326e+05
# 16111634120984322021             1.594049e+05              1.780567e+05
# ...                                       ...                       ...
# 6203773306922151309              0.000000e+00              0.000000e+00
# 17957731810262048765             0.000000e+00              0.000000e+00
# 2341387033982192385              0.000000e+00              0.000000e+00
# 6669415735134456905              0.000000e+00              0.000000e+00
# 10606136495986113371             0.000000e+00              0.000000e+00
#
#                       200525_Mou_Blank_01.mzML  200525_Rat_4h_03.mzML  \
# id
# 14739944058528654579              1.171156e+06           1.167791e+06
# 4157342119469212697               1.972586e+06           1.829177e+06
# 12302576997318969048              1.577991e+06           1.787740e+06
# 16994532679487893418              7.108326e+05           7.271477e+05
# 16111634120984322021              1.622634e+05           1.570629e+05
# ...                                        ...                    ...
# 6203773306922151309               0.000000e+00           0.000000e+00
# 17957731810262048765              0.000000e+00           0.000000e+00
# 2341387033982192385               0.000000e+00           0.000000e+00
# 6669415735134456905               0.000000e+00           0.000000e+00
# 10606136495986113371              0.000000e+00           0.000000e+00
#
#                       200525_Rat_4h_02.mzML  200525_Rat_Blank_03.mzML  \
# id
# 14739944058528654579           1.091322e+06              1.152289e+06
# 4157342119469212697            1.949732e+06              1.973152e+06
# 12302576997318969048           1.612728e+06              1.643221e+06
# 16994532679487893418           7.421345e+05              7.264196e+05
# 16111634120984322021           1.765407e+05              1.588426e+05
# ...                                     ...                       ...
# 6203773306922151309            0.000000e+00              0.000000e+00
# 17957731810262048765           0.000000e+00              0.000000e+00
# 2341387033982192385            0.000000e+00              0.000000e+00
# 6669415735134456905            0.000000e+00              0.000000e+00
# 10606136495986113371           0.000000e+00              0.000000e+00
#
#                       200525_Dog_4h_02.mzML
# id
# 14739944058528654579           1.181689e+06
# 4157342119469212697            1.821776e+06
# 12302576997318969048           1.540430e+06
# 16994532679487893418           6.990809e+05
# 16111634120984322021           1.539932e+05
# ...                                     ...
# 6203773306922151309            0.000000e+00
# 17957731810262048765           0.000000e+00
# 2341387033982192385            0.000000e+00
# 6669415735134456905            0.000000e+00
# 10606136495986113371           0.000000e+00
#
# [1312 rows x 29 columns]

# %% [markdown]
# Como o GNPS só funciona com _features_ que contêm espectros de fragmentação MS2, o primeiro passo é filtrar _features_ do seu `ConsensusMap` que não têm espectros MS2 anotados.

# %%
def filterConsensus(input_consensus='FeatureMatrix.consensusXML', out_consensus="filtered.consensusXML"):
    consensusXML_file = input_consensus
    
    consensus_map = oms.ConsensusMap()
    oms.ConsensusXMLFile().load(consensusXML_file, consensus_map)
    filtered_map = oms.ConsensusMap(consensus_map)
    filtered_map.clear(False)
    for feature in consensus_map:
        if feature.getPeptideIdentifications():
            filtered_map.push_back(feature)
    
    consensusXML_file = out_consensus
    oms.ConsensusXMLFile().store(consensusXML_file, filtered_map)

filterConsensus(input_consensus='FeatureMatrix.consensusXML', out_consensus="filtered.consensusXML")

# %%
def export2GNPS(mzML_files, consensus_map, consensusXML_file, out_dir='.'):
    oms.GNPSMGFFile().store(
        oms.String(consensusXML_file),
        [file.encode() for file in mzML_files],
        oms.String("MS2data.mgf"),
    )
    oms.GNPSQuantificationFile().store(consensus_map, f"{out_dir}/FeatureQuantificationTable.txt")
    oms.GNPSMetaValueFile().store(consensus_map, f"{out_dir}/MetaValueTable.tsv")

export2GNPS(mzML_files, consensus_map, "filtered.consensusXML", out_dir='results')

def export2IIMN(consensus_map):
    # for IIMN
    oms.IonIdentityMolecularNetworking().annotateConsensusMap(consensus_map)
    oms.IonIdentityMolecularNetworking().writeSupplementaryPairTable(
        consensus_map, "SupplementaryPairTable.csv"
    )

export2IIMN(consensus_map)
