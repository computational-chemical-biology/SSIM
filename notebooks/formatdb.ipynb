# %%
# !wget https://raw.githubusercontent.com/computational-chemical-biology/SSIM/refs/heads/master/api/formatdb.py

# %%
#from api.formatdb import * # for local loading
from formatdb import *
import pandas as pd
# Out:
# RDKit WARNING: [13:47:06] Enabling RDKit 2019.09.3 jupyter extensions

# %%
qdb = pd.read_csv('results/Query_114124_chw.tsv', sep='\t', header=None)

qdb.head()
# Out:
#                                                    0         1
# 0  CCC(C1=NN(C2=C1N=C(NC2=O)C3=C(C=CC(=C3)S(=O)(=...  BTMR0941
# 1  CCCC1=NN(C2=C1N=C(NC2=O)C3=C(C=CC(=C3)S(=O)(=O...  BTMR0042
# 2                                               CC=O  BTMR0042
# 3  CCCC1=NN(C2=C1N=C(NC2=O)C3=C(C=CC(=C3)S(=O)(=O...  BTMR1148
# 4  CCCC1=NN(C2=C1N=C(NC2=O)C3=C(C=CC(=C3)S(=O)(=O...  BTMR9031

# %%
db = formatdb('results/Query_114124_chw.tsv', 'ClassyFire', 'PSV')

# %%
pd.read_csv('results/Query_114124_chw.tsv_FORMATED.txt', sep='|')
# Out:
#      MonoisotopicMass                                              InChI  \
# 0          490.199839  InChI=1S/C22H30N6O5S/c1-5-16(29)18-19-20(27(4)...
# 1          446.173624  InChI=1S/C20H26N6O4S/c1-4-5-15-17-18(25(3)23-1...
# 2           44.026215                      InChI=1S/C2H4O/c1-2-3/h2H,1H3
# 3          490.199839  InChI=1S/C22H30N6O5S/c1-5-7-17-19-20(26(3)25-1...
# 4          460.189274  InChI=1S/C21H28N6O4S/c1-4-6-16-18-19(26(3)25-1...
# ..                ...                                                ...
# 409        474.168539  InChI=1S/C21H26N6O5S/c1-3-31-17-5-4-14(33(29,3...
# 410        504.179104  InChI=1S/C22H28N6O6S/c1-4-5-16-19-20(27(3)25-1...
# 411        474.168539  InChI=1S/C21H26N6O5S/c1-4-5-16-18-19(25-24-16)...
# 412        504.179104  InChI=1S/C22H28N6O6S/c1-4-5-16-19-20(27(3)25-1...
# 413        492.179104  InChI=1S/C21H28N6O6S/c1-3-4-15-18-19(25-24-15)...
#
#                                                 SMILES Identifier   InChIKey2  \
# ...
